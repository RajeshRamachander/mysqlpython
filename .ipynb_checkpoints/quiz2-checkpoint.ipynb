# %%
import pandas as pd

# %%
df = pd.read_csv('matches.csv')

# %%
f = df['toss_winner'] == 'Royal Challengers Bangalore'

df[f].count()
# Out:
# id                 81
# season             81
# city               80
# date               81
# team1              81
# team2              81
# toss_winner        81
# toss_decision      81
# result             81
# dl_applied         81
# winner             80
# win_by_runs        81
# win_by_wickets     81
# player_of_match    80
# venue              81
# umpire1            80
# umpire2            80
# umpire3            11
# dtype: int64

# %%
f = df['toss_winner'] == 'Royal Challengers Bangalore'

e = df['toss_decision'] == 'field'

# %%
z=df[f & e].count()

# %%
z
# Out:
# id                 61
# season             61
# city               60
# date               61
# team1              61
# team2              61
# toss_winner        61
# toss_decision      61
# result             61
# dl_applied         61
# winner             60
# win_by_runs        61
# win_by_wickets     61
# player_of_match    60
# venue              61
# umpire1            61
# umpire2            61
# umpire3            11
# dtype: int64

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
p = df['team1'] == 'Royal Challengers Bangalore'
q = df['team2'] == 'Royal Challengers Bangalore'
f = df['toss_winner'] != 'Royal Challengers Bangalore'

e = df['winner'] != 'Royal Challengers Bangalore'

# %%
x= df[(p | q) & f & e].count()

# %%
x
# Out:
# id                 56
# season             56
# city               55
# date               56
# team1              56
# team2              56
# toss_winner        56
# toss_decision      56
# result             56
# dl_applied         56
# winner             54
# win_by_runs        56
# win_by_wickets     56
# player_of_match    54
# venue              56
# umpire1            56
# umpire2            56
# umpire3            12
# dtype: int64
